# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('mydataheart.csv')

# %%
df.head()
# Out:
#              'Time','ECG2'
# 0      'hh:mm:ss.mmm','mV'
# 1   '[10:02:00.000]',0.000
# 2  '[10:02:00.004]',-0.010
# 3   '[10:02:00.008]',0.000
# 4   '[10:02:00.012]',0.025

# %%
df
# Out:
#                 'Time','ECG2'
# 0         'hh:mm:ss.mmm','mV'
# 1      '[10:02:00.000]',0.000
# 2     '[10:02:00.004]',-0.010
# 3      '[10:02:00.008]',0.000
# 4      '[10:02:00.012]',0.025
# 5      '[10:02:00.016]',0.040
# 6      '[10:02:00.020]',0.035
# 7      '[10:02:00.024]',0.050
# 8      '[10:02:00.028]',0.050
# 9      '[10:02:00.032]',0.050
# 10     '[10:02:00.036]',0.075
# 11     '[10:02:00.040]',0.080
# 12     '[10:02:00.044]',0.085
# 13     '[10:02:00.048]',0.110
# 14     '[10:02:00.052]',0.110
# 15     '[10:02:00.056]',0.110
# 16     '[10:02:00.060]',0.110
# 17     '[10:02:00.064]',0.125
# 18     '[10:02:00.068]',0.150
# 19     '[10:02:00.072]',0.170
# 20     '[10:02:00.076]',0.170
# 21     '[10:02:00.080]',0.185
# 22     '[10:02:00.084]',0.200
# 23     '[10:02:00.088]',0.230
# 24     '[10:02:00.092]',0.255
# 25     '[10:02:00.096]',0.270
# 26     '[10:02:00.100]',0.275
# 27     '[10:02:00.104]',0.295
# 28     '[10:02:00.108]',0.320
# 29     '[10:02:00.112]',0.320
# ...

# %%
x =df

# %%
plot.
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e7560efbd73a> in <module>()
# ----> 1 plot(x)
#       2 plt.show
#
# NameError: name 'plot' is not defined
