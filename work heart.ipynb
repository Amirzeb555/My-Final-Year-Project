# %%
import numpy as np

# %%
import pandas as pd

# %%
df =pd.read_csv('heart.csv')

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
np.shape(df)
# Out:
# (303, 14)

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.2 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import seaborn as sns

# %%
plt.figure(figsize=(18,10))
plt.subplot(2,5,1)
sns.histplot(heart['age'],kde=True)
plt.subplot(2,5,6)
sns.boxplot(heart['age'])
plt.subplot(2,5,2)
sns.histplot(heart['trtbps'],kde=True)
plt.subplot(2,5,7)
sns.boxplot(heart['trtbps'])
plt.subplot(2,5,3)
sns.histplot(heart['chol'],kde=True)
plt.subplot(2,5,8)
sns.boxplot(heart['chol'])
plt.subplot(2,5,4)
sns.histplot(heart['thalachh'],kde=True)
plt.subplot(2,5,9)
sns.boxplot(heart['thalachh'])
plt.subplot(2,5,5)
sns.histplot(heart['oldpeak'],kde=True)
plt.subplot(2,5,10)
sns.boxplot(heart['oldpeak'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-76e7fac7ffa1> in <module>()
#       1 plt.figure(figsize=(18,10))
#       2 plt.subplot(2,5,1)
# ----> 3 sns.histplot(heart['age'],kde=True)
#       4 plt.subplot(2,5,6)
#       5 sns.boxplot(heart['age'])
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,4,1)
sns.countplot(x='sex', data=df)
plt.subplot(2,4,2)
sns.countplot(x='cp', data=df)
plt.subplot(2,4,3)
sns.countplot(x='fbs', data=df)
plt.subplot(2,4,4)
sns.countplot(x='restecg', data=df)
plt.subplot(2,4,5)
sns.countplot(x='exng', data=df)
plt.subplot(2,4,6)
sns.countplot(x='slp', data=df)
plt.subplot(2,4,7)
sns.countplot(x='caa', data=df)
plt.subplot(2,4,8)
sns.countplot(x='thall', data=df)
plt.tight_layout()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True)

# %%
x = np.fromfile('\bidmc-congestive-heart-failure-database-1.0.0'\files, dtype=dat)

# %%
df2 =pd.read_table('C:\Users\Hp\Desktop\heart attack\bidmc-congestive-heart-failure-database-1.0.0\chf01.dat\chf02',header=None, sep='\s\s+', engine='python')

# %%
import re

# %%
import re

with open("C:\Users\Hp\Desktop\heart attack\bidmc-congestive-heart-failure-database-1.0.0\chf01.dat\chf02'.dat") as f:
    lines = f.readlines()
    text = "".join(lines)

regex = r"\|(.*?);"
matches = re.finditer(regex, text, re.MULTILINE | re.DOTALL)


data = []

for matchNum, match in enumerate(matches, start=1):
    for group in match.groups():
        data.append(group.split(","))

for d in data:
    print(d)

# %%
df_train=pd.read_table('C:\Users\admin\Desktop\game_test\game\apptype_train.dat',names=['s_no','deal_code','text'],sep='\t',encoding='utf-8')

# %%
f=open(r'C:\Users\admin\Desktop\game_test\game\apptype_train.dat',encoding='utf-8')
sentimentlist = []
for line in f:
    s = line.strip().split('\t')
    sentimentlist.append(s)
f.close()
df_train=pd.DataFrame(sentimentlist,columns=['s_no','deal_code','text'])

# %%
x = np.fromfile('C:\Users\Hp\Deheart attack\bidmc-congestive-heart-failure-database-1.0.0\chf01.dat\chf02.dat', 'dtype=dt')

# %%
datafile =pd.read_table('r\C:\Users\Hp\Desktop\heart attack\bidmc-congestive-heart-failure-database-1.0.0\files\chf01.dat\chf02.dat',sep=',')
# Out:
#   File "<ipython-input-12-442535cab24c>", line 1
#     datafile =pd.read_table('r\C:\Users\Hp\Desktop\heart attack\bidmc-congestive-heart-failure-database-1.0.0\files\chf01.dat\chf02.dat',sep=',')
#                            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 4-5: truncated \UXXXXXXXX escape

# %%
@@ -109,7 +109,9 @@ def get_data(filename, delim=',', column_name='None', encoding=None,
    >>> get_data(filepath, ignore_extension = True)
    array([530., 518., 506., ..., 492., 493., 494.])
    >>> 
    You can specify column names in the same way when using ignore_extension
    >>> filepath = resource_filename(__name__, 'data/data2.log')
    >>> data = get_data(filepath, column_name = 'hr', ignore_extension = True)
    '''
    file_ext = filename.split('.')[-1]
    if file_ext == 'csv' or file_ext == 'txt':

# %%
import heartpy as hp

# %%
import heartpy as hp

#if you have a ms-based timer:
    mstimer_data = hp.get_data('data2.csv', column_name='timer')
fs = hp.get_samplerate_mstimer(mstimer_data)
    print(fs)

#if you have a datetime-based timer:
    datetime_data = hp.get_data('data3.csv', column_name='datetime')
fs = hp.get_samplerate_datetime(datetime_data, timeformat='%Y-%m-%d %H:%M:%S.%f')
    print(fs)

# %%
import heartpy as hp

#if you have a ms-based timer:
    mstimer_data = hp.get_data('data2.csv', column_name='timer')
fs = hp.get_samplerate_mstimer(mstimer_data)
    print(fs)

#if you have a datetime-based timer:
    datetime_data = hp.get_data('data3.csv', column_name='datetime')
fs = hp.get_samplerate_datetime(datetime_data, timeformat='%Y-%m-%d %H:%M:%S.%f')
    print(fs)

# %%
0\chf01.dat\chf02'.datdf7 = pd.read_table("C:\Users\Hp\Desktop\heart attack\bidmc-congestive-heart-failure-database-1.0.", sep="\s+")
print(df7)

# %%
#If you want to load the data in the .dat file into a numpy array just do
#data = np.loadtxt(C )
#and you have a numpy array called data.

# %%
import pandas as pd
import numpy as np

# %%
#If you want to load the data in the .dat file into a numpy array just do
#data = pd.read_table('#If you want to load the data in the .dat file into a numpy array just do
data = pd.read_table('C:\Users\Hp\heart attack\bidmc-congestive-heart-failure-database-1.0.0\files\chf01.dat' )
#and you have a numpy array called data.' )
#and you have a numpy array called data.

# %%
data.to_csv("C:\Users\Hp\heart attack\bidmc-congestive-heart-failure-database-1.0.0\files\chf01.csv")
